# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle, os, sys
import matplotlib as mpl

# %%
from get_weight_isoscalar_constant_Emin_50GeV import *

# %%
indir = '/home/mliubar/projects/rpp-kenclark/hignight/atmo_flux'
numu = pickle.load(open(os.path.join(indir, 'Level5p_IC86.2013_genie_numu.14600.rlogL.pckl'),'rb'),encoding='latin1')
nue = pickle.load(open(os.path.join(indir, 'Level5p_IC86.2013_genie_nue.12600.rlogL.pckl'),'rb'),encoding='latin1')

# %%
plt.rcParams.update({'font.size': 20})
mpl.rcParams['mathtext.fontset'] = 'custom'
mpl.rcParams['mathtext.rm'] = 'Bitstream Vera Sans'
mpl.rcParams['mathtext.it'] = 'Bitstream Vera Sans:italic'
mpl.rcParams['mathtext.bf'] = 'Bitstream Vera Sans:bold'

mpl.rcParams['patch.linewidth'] = 2.5 
mpl.rcParams['lines.linewidth'] = 2.5

# %%
lw = 2.

# %%
asp_r = 1./12.*6.

left, width = 0.23, 0.85
bottom, height = 0.16, 0.75
bottom_h = bottom + height + 0.02
left_h = left + width + 0.02

rect1 = [left*asp_r, bottom-0.2, width, height]
rect2 = [left*asp_r, bottom, height, 0.2]

# %%
extrap_dict
# Out:
# {'NuBar': {'CC': {'lgEmax': 4.0,
#    'c': 1.178153660485833,
#    'linear': [-0.18559322536298592, 1.487475702757476],
#    'lgE_min': 1.68,
#    'poly_coef': array([ 7.22462639e-03, -1.31897377e-01,  1.00992328e+00, -4.17616609e+00,
#            9.92442115e+00, -1.31392339e+01,  8.30250668e+00, -3.03409597e-01])},
#   'NC': {'lgEmax': 4.0,
#    'c': 1.0374398215019272,
#    'linear': [-0.02399620848503104, 1.0774335023103123],
#    'lgE_min': 1.68,
#    'poly_coef': array([ 4.71328467e-03, -9.13581264e-02,  7.45672602e-01, -3.30336962e+00,
#            8.49888380e+00, -1.25222884e+01,  9.60634117e+00, -1.84651429e+00])}},
#  'Nu': {'CC': {'lgEmax': 4.0,
#    'c': 1.0368147631910702,
#    'linear': [-0.05096978352937504, 1.1217644024066953],
#    'lgE_min': 1.68,
#    'poly_coef': array([-7.57076288e-03,  1.27173205e-01, -8.88843229e-01,  3.36244042e+00,
#           -7.51510393e+00,  1.01415672e+01, -7.92374531e+00,  3.89490987e+00])},
#   'NC': {'lgEmax': 4.0,
#    'c': 0.970630232961796,
#    'linear': [0.0362361740272429, 0.9102366095830577],
#    'lgE_min': 1.68,
#    'poly_coef': array([-0.00440655,  0.07196249, -0.47771679,  1.65767028, -3.22654836,
#            3.52453471, -2.01841562,  1.44996594])}}}

# %%
numu.keys()
# Out:
# dict_keys(['ma_qe', 'mn_stopped_contained', 'weight', 'weight_noflux', 'AhtBY', 'ptype', 'GENIE_Ws', 'ma_res', 'rLogL', 'CV2uBY', 'MaNCEL', 'zenith', 'rLogL_good', 'CV1uBY', 'weight_e', 'GENIE_ys', 'energy', 'GENIE_xs', 'MaNCRES', 'delta_llh', 'GENIE_Q2s', 'GENIE_x', 'GENIE_y', 'reco_azimuth', 'MaCOHpi', 'interaction', 'GENIE_Q2', 'weight_mu', 'GENIE_W', 'reco_energy', 'BhtBY', 'reco_zenith'])

# %% [markdown]
# # xsec type separation

# %%
nu = {}
for k in numu.keys():
    if k == 'weight_e': continue
    if k == 'weight_mu': 
        nu['weight_emu'] = np.concatenate((nue['weight_e'],numu['weight_mu']))
        continue
    nu[k] = np.concatenate((nue[k],numu[k]))

# %%
nu.keys()
# Out:
# dict_keys(['ma_qe', 'mn_stopped_contained', 'weight', 'weight_noflux', 'AhtBY', 'ptype', 'GENIE_Ws', 'ma_res', 'rLogL', 'CV2uBY', 'MaNCEL', 'zenith', 'rLogL_good', 'CV1uBY', 'GENIE_ys', 'energy', 'GENIE_xs', 'MaNCRES', 'delta_llh', 'GENIE_Q2s', 'GENIE_x', 'GENIE_y', 'reco_azimuth', 'MaCOHpi', 'interaction', 'GENIE_Q2', 'weight_emu', 'GENIE_W', 'reco_energy', 'BhtBY', 'reco_zenith'])

# %%
def myargwh(cond):
    return np.transpose(np.argwhere(cond))[0]

# %%
# dis = (np.abs(numu['ma_res']).sum(axis=1) == 0)*(np.abs(numu['ma_qe']).sum(axis=1) == 0)
ind0 = myargwh(np.abs(nu['ma_res']).sum(axis=1) == 0)
ind1 = myargwh(np.abs(nu['ma_qe'][ind0]).sum(axis=1) == 0)
dis = ind0[ind1]

# %%
CCdis = dis[myargwh(nu['interaction'][dis]==1.)]
NCdis = dis[myargwh(nu['interaction'][dis]==2.)]
CCnotdis = ~dis[myargwh(nu['interaction'][~dis]==1.)]
NCnotdis = ~dis[myargwh(nu['interaction'][~dis]==2.)]

# %%
CCdisNu = CCdis[myargwh(nu['ptype'][CCdis]>0)]
NCdisNu = NCdis[myargwh(nu['ptype'][NCdis]>0)]
CCnotdisNu = CCnotdis[myargwh(nu['ptype'][CCnotdis]>0)]
NCnotdisNu = NCnotdis[myargwh(nu['ptype'][NCnotdis]>0)]

CCdisNuBar = CCdis[myargwh(nu['ptype'][CCdis]<0)]
NCdisNuBar = NCdis[myargwh(nu['ptype'][NCdis]<0)]
CCnotdisNuBar = CCnotdis[myargwh(nu['ptype'][CCnotdis]<0)]
NCnotdisNuBar = NCnotdis[myargwh(nu['ptype'][NCnotdis]<0)]

# %%
val = np.log10(nu['energy'])
glob_w = nu['weight_emu']

# %%
def get_w(weight=glob_w, nyears=1, 
          corr={'CCnu':False, 'CCnubar':False, 'NCnu':False, 'NCnubar':False}, \
          extr={'CCnu':'constant', 'CCnubar':'constant', 'NCnu':'constant', 'NCnubar':'constant'}):
    
    if nyears == 0:
        m = 1.
    else:
        m = m = 365*24*60.*60.*nyears
        
    wf = np.ones(len(glob_w))
    if corr['CCnu']:
        wf[CCdisNu] = wf[CCdisNu]*get_weight_iso(nu['energy'][CCdisNu], 
                                                 nu='Nu', current='CC', 
                                                 ext_type=extr['CCnu'])
    if corr['CCnubar']:
        wf[CCdisNuBar] = wf[CCdisNuBar]*get_weight_iso(nu['energy'][CCdisNuBar], 
                                                 nu='NuBar', current='CC', 
                                                 ext_type=extr['CCnubar'])
    if corr['NCnu']:
        wf[NCdisNu] = wf[NCdisNu]*get_weight_iso(nu['energy'][NCdisNu], 
                                                 nu='Nu', current='NC', 
                                                 ext_type=extr['NCnu'])
    if corr['NCnubar']:
        wf[NCdisNuBar] = wf[NCdisNuBar]*get_weight_iso(nu['energy'][NCdisNuBar], 
                                                 nu='NuBar', current='NC', 
                                                 ext_type=extr['NCnubar'])

    wr = weight*m*wf
    return wr, m

# %% [markdown]
# # plots

# %%
lgE_r = [0., 3.]
nb = 20

# %%
asp_r = 1./12.*6.

left, width = 0.25, 0.85
bottom, height = 0.09, 0.85
bottom_h = bottom + height + 0.02
left_h = left + width + 0.02

rect1 = [left*asp_r, bottom+0.3, height, height-0.2]
rect2 = [left*asp_r, bottom, height, 0.28]

# %%
def plot_true_en(corr={'CCnu':True, 'CCnubar':True, 'NCnu':True, 'NCnubar':True}, 
                title='all corrections applied'):
    fig = plt.figure(1, figsize=(7, 5))
    ax = plt.axes(rect1)

    ax.set_xlim(0.,3.1)
    # ax.set_ylim(y_r)
    ax.set_title(title)
    ax.set_ylabel('counts')
    plt.xticks(visible=False)

    w0, m  = get_w(nyears=1.)
    wcorr_c, _ = get_w(nyears=1., 
                  corr=corr, \
                  extr={'CCnu':'constant', 'CCnubar':'constant', 'NCnu':'constant', 'NCnubar':'constant'})
    wcorr_lin, _ = get_w(nyears=1., 
                  corr=corr, \
                  extr={'CCnu':'linear', 'CCnubar':'linear', 'NCnu':'linear', 'NCnubar':'linear'})
    
    h0, be, _ = plt.hist(val, nb, lgE_r, 
                      weights=w0,
                      histtype='step', color='r', linestyle='-',
                        label='not corr.')
    
    hc, be, _ = plt.hist(val, nb, lgE_r, 
                      weights=wcorr_c,
                      histtype='step', color='limegreen', linestyle='--',
                        label='constant extr.')
    hl, be, _ = plt.hist(val, nb, lgE_r, 
                      weights=wcorr_lin,
                      histtype='step', color='b', linestyle='--',
                        label='linear extr.')


    bc = be[:-1] + (be[1]-be[0])/2.

    plt.grid(alpha=0.2)
    ax.axvline(1.68, c='k')
    plt.legend(fontsize=15)
    
    ax2 = plt.axes(rect2)

    ax2.set_xlim(0.,3.1)
    ax2.set_ylim(-50., 250.)
    ax2.set_yticks([-50., 0., 100., 200.])
    ax2.set_xlabel('log10(true E), GeV')
    ax2.set_ylabel('(corr. -\n not corr.)')

    # sigma0, _ = np.histogram(val, nb, lgE_r)
    # sigma0 = np.sqrt(sigma0)*w0

    sigma0 = np.sqrt(h0)

    ax2.step(be, np.concatenate(([0.],(h0-h0))), color='r', linestyle='-')
    ax2.step(be, np.concatenate(([(hc-h0)[0]],(hc-h0))), color='limegreen', linestyle='--')
    ax2.step(be, np.concatenate(([(hl-h0)[0]],(hl-h0))), color='b', linestyle='--')
    # ax2.step(be[1:], (hc-h0)/sigma0, color='r')

    plt.grid(alpha=0.2)
    ax2.axvline(1.68, c='k')
    plt.show()
    
    return 0

# %%
plot_true_en(corr={'CCnu':True, 'CCnubar':True, 'NCnu':True, 'NCnubar':True}, 
                title='all corrections applied')
# Out:
# 0

# %%
plot_true_en(corr={'CCnu':True, 'CCnubar':False, 'NCnu':False, 'NCnubar':False}, 
                title='only CC Nu corrected')
# Out:
# 0

# %%
plot_true_en(corr={'CCnu':False, 'CCnubar':True, 'NCnu':False, 'NCnubar':False}, 
                title='only CC NuBar corrected')
# Out:
# 0

# %%
plot_true_en(corr={'CCnu':False, 'CCnubar':False, 'NCnu':True, 'NCnubar':False}, 
                title='only NC Nu corrected')
# Out:
# 0

# %%
plot_true_en(corr={'CCnu':False, 'CCnubar':False, 'NCnu':False, 'NCnubar':True}, 
                title='only NC NuBar corrected')
# Out:
# 0

# %%
def plot_reco_en(plot_val = np.log10(nu['reco_energy']),
                 corr={'CCnu':True, 'CCnubar':True, 'NCnu':True, 'NCnubar':True}, 
                 title='all corrections applied'):
    fig = plt.figure(1, figsize=(7, 5))
    ax = plt.axes(rect1)

    ax.set_xlim(0.,3.1)
    # ax.set_ylim(y_r)
    ax.set_title(title)
    ax.set_ylabel('counts')
    plt.xticks(visible=False)

    w0, m  = get_w(nyears=1.)
    wcorr_c, _ = get_w(nyears=1., 
                  corr=corr, \
                  extr={'CCnu':'constant', 'CCnubar':'constant', 'NCnu':'constant', 'NCnubar':'constant'})
    wcorr_lin, _ = get_w(nyears=1., 
                  corr=corr, \
                  extr={'CCnu':'linear', 'CCnubar':'linear', 'NCnu':'linear', 'NCnubar':'linear'})
    
    h0, be, _ = plt.hist(plot_val, nb, lgE_r, 
                      weights=w0,
                      histtype='step', color='r', linestyle='-',
                        label='not corr.')
    
    hc, be, _ = plt.hist(plot_val, nb, lgE_r, 
                      weights=wcorr_c,
                      histtype='step', color='limegreen', linestyle='--',
                        label='constant extr.')
    hl, be, _ = plt.hist(plot_val, nb, lgE_r, 
                      weights=wcorr_lin,
                      histtype='step', color='b', linestyle='--',
                        label='linear extr.')


    bc = be[:-1] + (be[1]-be[0])/2.

    plt.grid(alpha=0.2)
    ax.axvline(1.68, c='k', linestyle=':')
    plt.legend(fontsize=15)
    
    ax2 = plt.axes(rect2)

    ax2.set_xlim(0.,3.1)
    ax2.set_ylim(-50., 250.)
    ax2.set_yticks([-50., 0., 100., 200.])
    ax2.set_xlabel('log10(reco E), GeV')
    ax2.set_ylabel('(corr. -\n not corr.)')

    # sigma0, _ = np.histogram(val, nb, lgE_r)
    # sigma0 = np.sqrt(sigma0)*w0

    sigma0 = np.sqrt(h0)

    ax2.step(be, np.concatenate(([0.],(h0-h0))), color='r', linestyle='-')
    ax2.step(be, np.concatenate(([(hc-h0)[0]],(hc-h0))), color='limegreen', linestyle='--')
    ax2.step(be, np.concatenate(([(hl-h0)[0]],(hl-h0))), color='b', linestyle='--')
    # ax2.step(be[1:], (hc-h0)/sigma0, color='r')

    plt.grid(alpha=0.2)
    ax2.axvline(1.68, c='k', linestyle=':')
    plt.show()
    
    return 0
# Out:
# /home/mliubar/myjupyter_py3/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log10
#   """Entry point for launching an IPython kernel.

# %%
plot_reco_en(corr={'CCnu':True, 'CCnubar':True, 'NCnu':True, 'NCnubar':True}, 
                title='all corrections applied')
# Out:
# 0

# %%
plot_reco_en(corr={'CCnu':True, 'CCnubar':False, 'NCnu':False, 'NCnubar':False}, 
                title='only CC Nu corrected')
# Out:
# 0

# %%
plot_reco_en(corr={'CCnu':False, 'CCnubar':True, 'NCnu':False, 'NCnubar':False}, 
                title='only CC NuBar corrected')
# Out:
# 0

# %%
plot_reco_en(corr={'CCnu':False, 'CCnubar':False, 'NCnu':True, 'NCnubar':False}, 
                title='only NC Nu corrected')
# Out:
# 0

# %%
plot_reco_en(corr={'CCnu':False, 'CCnubar':False, 'NCnu':False, 'NCnubar':True}, 
                title='only NC NuBar corrected')
# Out:
# 0

# %%
zen_r = [0.,180.]

# %%
def plot_reco_zen(plot_val = (nu['reco_zenith']*180/np.pi),
                 corr={'CCnu':True, 'CCnubar':True, 'NCnu':True, 'NCnubar':True}, 
                 title='all corrections applied'):
    fig = plt.figure(1, figsize=(7, 5))
    ax = plt.axes(rect1)

    ax.set_xlim(0.,180.)
    # ax.set_ylim(y_r)
    ax.set_title(title)
    ax.set_ylabel('counts')
    plt.xticks(visible=False)

    w0, m  = get_w(nyears=1.)
    wcorr_c, _ = get_w(nyears=1., 
                  corr=corr, \
                  extr={'CCnu':'constant', 'CCnubar':'constant', 'NCnu':'constant', 'NCnubar':'constant'})
    wcorr_lin, _ = get_w(nyears=1., 
                  corr=corr, \
                  extr={'CCnu':'linear', 'CCnubar':'linear', 'NCnu':'linear', 'NCnubar':'linear'})
    
    h0, be, _ = plt.hist(plot_val, nb, zen_r, 
                      weights=w0,
                      histtype='step', color='r', linestyle='-',
                        label='not corr.')
    
    hc, be, _ = plt.hist(plot_val, nb, zen_r, 
                      weights=wcorr_c,
                      histtype='step', color='limegreen', linestyle='--',
                        label='constant extr.')
    hl, be, _ = plt.hist(plot_val, nb, zen_r, 
                      weights=wcorr_lin,
                      histtype='step', color='b', linestyle='--',
                        label='linear extr.')


    bc = be[:-1] + (be[1]-be[0])/2.

    plt.grid(alpha=0.2)
#     ax.axvline(1.68, c='k', linestyle=':')
    plt.legend(fontsize=15, loc=2)
    
    ax2 = plt.axes(rect2)

    ax2.set_xlim(0.,180.)
    ax2.set_ylim(-50., 250.)
    ax2.set_yticks([-50., 0., 100., 200.])
    ax2.set_xlabel('reco zenith, deg')
    ax2.set_ylabel('(corr. -\n not corr.)')

    # sigma0, _ = np.histogram(val, nb, lgE_r)
    # sigma0 = np.sqrt(sigma0)*w0

    sigma0 = np.sqrt(h0)

    ax2.step(be, np.concatenate(([0.],(h0-h0))), color='r', linestyle='-')
    ax2.step(be, np.concatenate(([(hc-h0)[0]],(hc-h0))), color='limegreen', linestyle='--')
    ax2.step(be, np.concatenate(([(hl-h0)[0]],(hl-h0))), color='b', linestyle='--')
    # ax2.step(be[1:], (hc-h0)/sigma0, color='r')

    plt.grid(alpha=0.2)
#     ax2.axvline(1.68, c='k', linestyle=':')
    plt.show()
    
    return 0

# %%
plot_reco_zen(corr={'CCnu':True, 'CCnubar':True, 'NCnu':True, 'NCnubar':True}, 
                title='all corrections applied')
# Out:
# 0

# %%
plot_reco_zen(corr={'CCnu':True, 'CCnubar':False, 'NCnu':False, 'NCnubar':False}, 
                title='only CC Nu corrected')
# Out:
# 0

# %%
plot_reco_zen(corr={'CCnu':False, 'CCnubar':True, 'NCnu':False, 'NCnubar':False}, 
                title='only CC NuBar corrected')
# Out:
# 0

# %%
plot_reco_zen(corr={'CCnu':False, 'CCnubar':False, 'NCnu':True, 'NCnubar':False}, 
                title='only NC Nu corrected')
# Out:
# 0

# %%
plot_reco_zen(corr={'CCnu':False, 'CCnubar':False, 'NCnu':False, 'NCnubar':True}, 
                title='only NC NuBar corrected')
# Out:
# 0

# %%
dllh_r = [-3., 10.]

# %%
def plot_reco_dllh(plot_val = nu['delta_llh'],
                 corr={'CCnu':True, 'CCnubar':True, 'NCnu':True, 'NCnubar':True}, 
                 title='all corrections applied'):
    fig = plt.figure(1, figsize=(7, 5))
    ax = plt.axes(rect1)

    ax.set_xlim(dllh_r)
    # ax.set_ylim(y_r)
    ax.set_title(title)
    ax.set_ylabel('counts')
    plt.xticks(visible=False)

    w0, m  = get_w(nyears=1.)
    wcorr_c, _ = get_w(nyears=1., 
                  corr=corr, \
                  extr={'CCnu':'constant', 'CCnubar':'constant', 'NCnu':'constant', 'NCnubar':'constant'})
    wcorr_lin, _ = get_w(nyears=1., 
                  corr=corr, \
                  extr={'CCnu':'linear', 'CCnubar':'linear', 'NCnu':'linear', 'NCnubar':'linear'})
    
    h0, be, _ = plt.hist(plot_val, nb, dllh_r, 
                      weights=w0,
                      histtype='step', color='r', linestyle='-',
                        label='not corr.')
    
    hc, be, _ = plt.hist(plot_val, nb, dllh_r, 
                      weights=wcorr_c,
                      histtype='step', color='limegreen', linestyle='--',
                        label='constant extr.')
    hl, be, _ = plt.hist(plot_val, nb, dllh_r, 
                      weights=wcorr_lin,
                      histtype='step', color='b', linestyle='--',
                        label='linear extr.')


    bc = be[:-1] + (be[1]-be[0])/2.

    plt.grid(alpha=0.2)
    ax.axvline(2., c='k', linestyle='-')
    plt.legend(fontsize=15, loc=1)
    
    ax2 = plt.axes(rect2)

    ax2.set_xlim(dllh_r)
    ax2.set_ylim(-50., 250.)
    ax2.set_yticks([-50., 0., 100., 200.])
    ax2.set_xlabel(r'\Delta LLH')
    ax2.set_ylabel('(corr. -\n not corr.)')

    # sigma0, _ = np.histogram(val, nb, lgE_r)
    # sigma0 = np.sqrt(sigma0)*w0

    sigma0 = np.sqrt(h0)

    ax2.step(be, np.concatenate(([0.],(h0-h0))), color='r', linestyle='-')
    ax2.step(be, np.concatenate(([(hc-h0)[0]],(hc-h0))), color='limegreen', linestyle='--')
    ax2.step(be, np.concatenate(([(hl-h0)[0]],(hl-h0))), color='b', linestyle='--')
    # ax2.step(be[1:], (hc-h0)/sigma0, color='r')

    plt.grid(alpha=0.2)
    ax2.axvline(2., c='k', linestyle='-')
    plt.show()
    
    return 0

# %%
plot_reco_dllh(corr={'CCnu':True, 'CCnubar':True, 'NCnu':True, 'NCnubar':True}, 
                title='all corrections applied')
# Out:
# 0

# %%
plot_reco_dllh(corr={'CCnu':True, 'CCnubar':False, 'NCnu':False, 'NCnubar':False}, 
                title='only CC Nu corrected')
# Out:
# 0

# %%
plot_reco_dllh(corr={'CCnu':False, 'CCnubar':True, 'NCnu':False, 'NCnubar':False}, 
                title='only CC NuBar corrected')
# Out:
# 0

# %%
plot_reco_dllh(corr={'CCnu':False, 'CCnubar':False, 'NCnu':True, 'NCnubar':False}, 
                title='only NC Nu corrected')
# Out:
# 0

# %%
plot_reco_dllh(corr={'CCnu':False, 'CCnubar':False, 'NCnu':False, 'NCnubar':True}, 
                title='only NC NuBar corrected')
# Out:
# 0

# %%
max(nu['delta_llh'])
# Out:
# 1297.8571820557283

# %%
def plot_reco_dllh2(plot_val = nu['delta_llh'],
                 corr={'CCnu':True, 'CCnubar':True, 'NCnu':True, 'NCnubar':True}, 
                 title='all corrections applied'):
    fig = plt.figure(1, figsize=(7, 5))
    ax = plt.axes(rect1)

    ax.set_xlim(dllh_r)
    # ax.set_ylim(y_r)
    ax.set_title(title)
    ax.set_ylabel('counts')
    plt.xticks(visible=False)
    
    bins = np.array([-3.,2., max(nu['delta_llh'])])

    w0, m  = get_w(nyears=1.)
    wcorr_c, _ = get_w(nyears=1., 
                  corr=corr, \
                  extr={'CCnu':'constant', 'CCnubar':'constant', 'NCnu':'constant', 'NCnubar':'constant'})
    wcorr_lin, _ = get_w(nyears=1., 
                  corr=corr, \
                  extr={'CCnu':'linear', 'CCnubar':'linear', 'NCnu':'linear', 'NCnubar':'linear'})
    
    h0, be, _ = plt.hist(plot_val, bins, 
                      weights=w0,
                      histtype='step', color='r', linestyle='-',
                        label='not corr.')
    
    hc, be, _ = plt.hist(plot_val, bins, 
                      weights=wcorr_c,
                      histtype='step', color='limegreen', linestyle='--',
                        label='constant extr.')
    hl, be, _ = plt.hist(plot_val, bins, 
                      weights=wcorr_lin,
                      histtype='step', color='b', linestyle='--',
                        label='linear extr.')


    bc = be[:-1] + (be[1]-be[0])/2.

    ct0 = h0[0]/h0[1]
    ctc = hc[0]/hc[1]
    ctl = hl[0]/hl[1]
    
    sig_ct0 = ct0*np.sqrt(1./h0[0]+1./h0[1])
    sig_ctc = ctc*np.sqrt(1./hc[0]+1./hc[1])
    sig_ctl = ctl*np.sqrt(1./hl[0]+1./hl[1])
    
    plt.text(-2.5, 8000., ('casc / tr ='), color='k')
    plt.text(-2.5, 6800., ('{:.2f}'.format(ct0)+r'$\pm${:.2f}'.format(sig_ct0)), color='red')
    plt.text(-2.5, 5600., ('{:.2f}'.format(ctc)+r'$\pm${:.2f}'.format(sig_ctc)), color='limegreen')
    plt.text(-2.5, 4400., ('{:.2f}'.format(ctl)+r'$\pm${:.2f}'.format(sig_ctl)), color='b')
    
    plt.grid(alpha=0.2)
    ax.axvline(2., c='k', linestyle='-')
    plt.legend(fontsize=15, loc=4)
    
    ax2 = plt.axes(rect2)

    ax2.set_xlim(dllh_r)
    ax2.set_ylim(-40., 800.)
    ax2.set_yticks([0., 400., 800.])
    ax2.set_xlabel(r'\Delta LLH')
    ax2.set_ylabel('(corr. -\n not corr.)')

    # sigma0, _ = np.histogram(val, nb, lgE_r)
    # sigma0 = np.sqrt(sigma0)*w0

    sigma0 = np.sqrt(h0)

    ax2.step(be, np.concatenate(([0.],(h0-h0))), color='r', linestyle='-')
    ax2.step(be, np.concatenate(([(hc-h0)[0]],(hc-h0))), color='limegreen', linestyle='--')
    ax2.step(be, np.concatenate(([(hl-h0)[0]],(hl-h0))), color='b', linestyle='--')
    # ax2.step(be[1:], (hc-h0)/sigma0, color='r')

    plt.grid(alpha=0.2)
    ax2.axvline(2., c='k', linestyle='-')
    plt.show()
    
    return 0

# %%
plot_reco_dllh2(corr={'CCnu':True, 'CCnubar':True, 'NCnu':True, 'NCnubar':True}, 
                title='all corrections applied')
# Out:
# 0

# %%
plot_reco_dllh2(corr={'CCnu':True, 'CCnubar':False, 'NCnu':False, 'NCnubar':False}, 
                title='only CC Nu corrected')
# Out:
# 0

# %%
plot_reco_dllh2(corr={'CCnu':False, 'CCnubar':True, 'NCnu':False, 'NCnubar':False}, 
                title='only CC NuBar corrected')
# Out:
# 0

# %%
plot_reco_dllh2(corr={'CCnu':False, 'CCnubar':False, 'NCnu':True, 'NCnubar':False}, 
                title='only NC Nu corrected')
# Out:
# 0

# %%
plot_reco_dllh2(corr={'CCnu':False, 'CCnubar':False, 'NCnu':False, 'NCnubar':True}, 
                title='only NC NuBar corrected')
# Out:
# 0

# %% [markdown]
# # old plots

# %%
def plot_reco_dllh2(plot_val = nu['delta_llh'],
                 corr={'CCnu':True, 'CCnubar':True, 'NCnu':True, 'NCnubar':True}, 
                 title='all corrections applied'):
    fig = plt.figure(1, figsize=(7, 5))
    ax = plt.axes(rect1)

    ax.set_xlim(dllh_r)
    # ax.set_ylim(y_r)
    ax.set_title(title)
    ax.set_ylabel('counts')
    plt.xticks(visible=False)
    
    bins = np.array([-3.,2., max(nu['delta_llh'])])

    w0, m  = get_w(nyears=1.)
    wcorr_c, _ = get_w(nyears=1., 
                  corr=corr, \
                  extr={'CCnu':'constant', 'CCnubar':'constant', 'NCnu':'constant', 'NCnubar':'constant'})
    wcorr_lin, _ = get_w(nyears=1., 
                  corr=corr, \
                  extr={'CCnu':'linear', 'CCnubar':'linear', 'NCnu':'linear', 'NCnubar':'linear'})
    
    h0, be, _ = plt.hist(plot_val, bins, 
                      weights=w0,
                      histtype='step', color='r', linestyle='-',
                        label='not corr.')
    
    hc, be, _ = plt.hist(plot_val, bins, 
                      weights=wcorr_c,
                      histtype='step', color='limegreen', linestyle='--',
                        label='constant extr.')
    hl, be, _ = plt.hist(plot_val, bins, 
                      weights=wcorr_lin,
                      histtype='step', color='b', linestyle='--',
                        label='linear extr.')


    bc = be[:-1] + (be[1]-be[0])/2.

    plt.grid(alpha=0.2)
    ax.axvline(2., c='k', linestyle='-')
    plt.legend(fontsize=15, loc=4)
    
    ax2 = plt.axes(rect2)

    ax2.set_xlim(dllh_r)
    ax2.set_ylim(0.9, 1.1)
    ax2.set_xlabel(r'\Delta LLH')
    ax2.set_ylabel('(corr. /\n not corr.)')

    # sigma0, _ = np.histogram(val, nb, lgE_r)
    # sigma0 = np.sqrt(sigma0)*w0

    sigma0 = np.sqrt(h0)

    ax2.step(be, np.concatenate(([1.],(h0/h0))), color='r', linestyle='-')
    ax2.step(be, np.concatenate(([(hc/h0)[0]],(hc/h0))), color='limegreen', linestyle='--')
    ax2.step(be, np.concatenate(([(hl/h0)[0]],(hl/h0))), color='b', linestyle='--')
#     print (hc/h0)
    # ax2.step(be[1:], (hc-h0)/sigma0, color='r')

    plt.grid(alpha=0.2)
    ax2.axvline(2., c='k', linestyle='-')
    plt.show()
    
    return 0

# %%
fig = plt.figure(1, figsize=(7, 5))
ax = plt.axes(rect1)

ax.set_xlim(0.,3.1)
# ax.set_ylim(y_r)
ax.set_title('all corrections applied')
ax.set_ylabel('counts')
plt.xticks(visible=False)

w0, m  = get_w(nyears=1.)
wcorr_c, _ = get_w(nyears=1., 
              corr={'CCnu':True, 'CCnubar':True, 'NCnu':True, 'NCnubar':True}, \
              extr={'CCnu':'constant', 'CCnubar':'constant', 'NCnu':'constant', 'NCnubar':'constant'})
wcorr_lin, _ = get_w(nyears=1., 
              corr={'CCnu':True, 'CCnubar':True, 'NCnu':True, 'NCnubar':True}, \
              extr={'CCnu':'linear', 'CCnubar':'linear', 'NCnu':'linear', 'NCnubar':'linear'})

hc, be, _ = plt.hist(val, nb, lgE_r, 
                  weights=wcorr_c,
                  histtype='step', color='g', linestyle='--',
                    label='not corr.')
hl, be, _ = plt.hist(val, nb, lgE_r, 
                  weights=wcorr_lin,
                  histtype='step', color='b', linestyle='--',
                    label='constant extr.')
h0, be, _ = plt.hist(val, nb, lgE_r, 
                  weights=w0,
                  histtype='step', color='r', linestyle='-',
                    label='linear extr.')

bc = be[:-1] + (be[1]-be[0])/2.

plt.grid(alpha=0.2)
ax.axvline(1.68, c='k')

ax2 = plt.axes(rect2)

ax2.set_xlim(0.,3.1)
# ax2.set_ylim(0.75, 1.25)
# ax2.set_yticks([0.8, 0.9, 1.0, 1.1, 1.2])
ax2.set_xlabel('log10(E), GeV')
ax2.set_ylabel('(corr. -\n not corr.)')

# sigma0, _ = np.histogram(val, nb, lgE_r)
# sigma0 = np.sqrt(sigma0)*w0

sigma0 = np.sqrt(h0)

ax2.step(be, np.concatenate(([0.],(h0-h0))), color='r', linestyle='-')
ax2.step(be, np.concatenate(([(hc-h0)[0]],(hc-h0))), color='g', linestyle='--')
ax2.step(be, np.concatenate(([(hl-h0)[0]],(hl-h0))), color='b', linestyle='--')
# ax2.step(be[1:], (hc-h0)/sigma0, color='r')

plt.grid(alpha=0.2)
ax2.axvline(1.68, c='k')
plt.show()

# %%
fig = plt.figure(1, figsize=(7, 5))
ax = plt.axes(rect1)

ax.set_xlim(0.,3.)
# ax.set_ylim(y_r)
ax.set_title('fit + constant extrapolation')
ax.set_ylabel('counts')
plt.xticks(visible=False)

w0, m  = get_w(nyears=1.)
wcorr, _ = get_w(nyears=1., 
              corr={'CCnu':True, 'CCnubar':True, 'NCnu':True, 'NCnubar':True}, \
              extr={'CCnu':'constant', 'CCnubar':'constant', 'NCnu':'constant', 'NCnubar':'constant'})

h0, be, _ = plt.hist(val, nb, lgE_r, 
                  weights=w0,
                  histtype='step', color='r', linestyle='-')
hc, be, _ = plt.hist(val, nb, lgE_r, 
                  weights=wcorr,
                  histtype='step', color='r', linestyle='--')

bc = be[:-1] + (be[1]-be[0])/2.

plt.grid(alpha=0.2)
ax2 = plt.axes(rect2)

ax2.set_xlim(0.,3.)
# ax2.set_ylim(0.75, 1.25)
# ax2.set_yticks([0.8, 0.9, 1.0, 1.1, 1.2])
ax2.set_xlabel('log10(E), GeV')
ax2.set_ylabel('(corr. -\n not corr.)')

# sigma0, _ = np.histogram(val, nb, lgE_r)
# sigma0 = np.sqrt(sigma0)*w0

sigma0 = np.sqrt(h0)

ax2.step(be[1:], (hc-h0), color='r')
# ax2.step(be[1:], (hc-h0)/sigma0, color='r')

plt.grid(alpha=0.2)
plt.show()

# %%
fig = plt.figure(1, figsize=(7, 5))
ax = plt.axes(rect1)

ax.set_xlim(0.,3.)
# ax.set_ylim(y_r)
ax.set_title('fit + constant extrapolation')
ax.set_ylabel('counts')
plt.xticks(visible=False)

w0, m  = get_w(nyears=1.)
wcorr, _ = get_w(nyears=1., 
              corr={'CCnu':True, 'CCnubar':True, 'NCnu':True, 'NCnubar':True}, \
              extr={'CCnu':'linear', 'CCnubar':'linear', 'NCnu':'linear', 'NCnubar':'linear'})

h0, be, _ = plt.hist(val, nb, lgE_r, 
                  weights=w0,
                  histtype='step', color='r', linestyle='-')
hc, be, _ = plt.hist(val, nb, lgE_r, 
                  weights=wcorr,
                  histtype='step', color='r', linestyle='--')

bc = be[:-1] + (be[1]-be[0])/2.

plt.grid(alpha=0.2)
ax2 = plt.axes(rect2)

ax2.set_xlim(0.,3.)
# ax2.set_ylim(0.75, 1.25)
# ax2.set_yticks([0.8, 0.9, 1.0, 1.1, 1.2])
ax2.set_xlabel('log10(E), GeV')
ax2.set_ylabel('(corr. -\n not corr.)')

# sigma0, _ = np.histogram(val, nb, lgE_r)
# sigma0 = np.sqrt(sigma0)*w0

sigma0 = np.sqrt(h0)

ax2.step(be[1:], (hc-h0), color='r')
# ax2.step(be[1:], (hc-h0)/sigma0, color='r')

plt.grid(alpha=0.2)
plt.show()

# %%
fig = plt.figure(1, figsize=(7, 5))
ax = plt.axes(rect1)



hcc0 = plt.hist(np.log10(numu['energy'][dis][CCdis][CCdisNu]), nb, lgE_r, 
         weights=numu['weight_mu'][dis][CCdis][CCdisNu],
         histtype='step', color='r')
# hnc0 = plt.hist(np.log10(numu['energy'][dis][NCdis][NCdisNu]), nb, lgE_r, 
#          weights=numu['weight_mu'][dis][NCdis][NCdisNu],
#          histtype='step', color='orange')

hcc_c = plt.hist(np.log10(numu['energy'][dis][CCdis][CCdisNu]), nb, lgE_r, 
         weights=numu['weight_mu'][dis][CCdis][CCdisNu]*w_CCNu_c,
         histtype='step', color='r', linestyle=':')
# hnc_c = plt.hist(np.log10(numu['energy'][dis][NCdis][NCdisNu]), nb, lgE_r, 
#          weights=numu['weight_mu'][dis][NCdis][NCdisNu]*w_NCNu_c,
#          histtype='step', color='orange', linestyle=':')

hcc_lin = plt.hist(np.log10(numu['energy'][dis][CCdis][CCdisNu]), nb, lgE_r, 
         weights=numu['weight_mu'][dis][CCdis][CCdisNu]*w_CCNu_lin,
         histtype='step', color='r', linestyle='--')
# hnc_lin = plt.hist(np.log10(numu['energy'][dis][NCdis][NCdisNu]), nb, lgE_r, 
#          weights=numu['weight_mu'][dis][NCdis][NCdisNu]*w_NCNu_lin,
#          histtype='step', color='orange', linestyle='--')

plt.grid(alpha=0.2)
ax2 = plt.axes(rect2)

ax2.step(hcc0[1][:-1], hcc_lin[0]-hcc_c[0], color='r')

ax2.step(hcc0[1][:-1], hcc_c[0]-hcc0[0], color='g')
ax2.step(hcc0[1][:-1], hcc_lin[0]-hcc0[0], color='y')
ax2.step(hnc0[1][:-1], hnc_c[0]-hnc_lin[0], color='orange', linestyle=':')

plt.grid(alpha=0.2)
plt.show()

# %%
fig = plt.figure(1, figsize=(7, 5))
ax = plt.axes(rect1)



hcc0 = plt.hist(np.log10(numu['energy'][dis][CCdis][CCdisNu]), nb, lgE_r, 
         weights=numu['weight_mu'][dis][CCdis][CCdisNu],
         histtype='step', color='r')
hnc0 = plt.hist(np.log10(numu['energy'][dis][NCdis][NCdisNu]), nb, lgE_r, 
         weights=numu['weight_mu'][dis][NCdis][NCdisNu],
         histtype='step', color='orange')

hcc_c = plt.hist(np.log10(numu['energy'][dis][CCdis][CCdisNu]), nb, lgE_r, 
         weights=numu['weight_mu'][dis][CCdis][CCdisNu]*w_CCNu_c,
         histtype='step', color='r', linestyle=':')
hnc_c = plt.hist(np.log10(numu['energy'][dis][NCdis][NCdisNu]), nb, lgE_r, 
         weights=numu['weight_mu'][dis][NCdis][NCdisNu]*w_NCNu_c,
         histtype='step', color='orange', linestyle=':')

hcc_lin = plt.hist(np.log10(numu['energy'][dis][CCdis][CCdisNu]), nb, lgE_r, 
         weights=numu['weight_mu'][dis][CCdis][CCdisNu]*w_CCNu_lin,
         histtype='step', color='r', linestyle='--')
hnc_lin = plt.hist(np.log10(numu['energy'][dis][NCdis][NCdisNu]), nb, lgE_r, 
         weights=numu['weight_mu'][dis][NCdis][NCdisNu]*w_NCNu_lin,
         histtype='step', color='orange', linestyle='--')

ax2 = plt.axes(rect2)

ax2.step(hcc0[1][:-1], hcc_lin[0]-hcc_c[0], color='r')

ax2.step(hcc0[1][:-1], hcc_c[0]-hcc0[0], color='g')
ax2.step(hcc0[1][:-1], hcc_lin[0]-hcc0[0], color='y')
ax2.step(hnc0[1][:-1], hnc_c[0]-hnc_lin[0], color='orange', linestyle=':')

plt.grid(alpha=0.2)
plt.show()

# %%
nb=30

# %%
fig = plt.figure(1, figsize=(7, 5))
ax = plt.axes(rect1)



hcc0 = plt.hist(np.log10(numu['reco_energy'][dis][CCdis][CCdisNu]), nb, lgE_r, 
         weights=numu['weight_mu'][dis][CCdis][CCdisNu],
         histtype='step', color='r')
hnc0 = plt.hist(np.log10(numu['reco_energy'][dis][NCdis][NCdisNu]), nb, lgE_r, 
         weights=numu['weight_mu'][dis][NCdis][NCdisNu],
         histtype='step', color='orange')

# plt.hist(np.log10(numu['reco_energy'][~dis][CCnotdis][CCnotdisNu]), nb, lgE_r, 
#          weights=numu['weight_mu'][~dis][CCnotdis][CCnotdisNu],
#          histtype='step', color='b')
# plt.hist(np.log10(numu['reco_energy'][~dis][NCnotdis][NCnotdisNu]), nb, lgE_r, 
#          weights=numu['weight_mu'][~dis][NCnotdis][NCnotdisNu],
#          histtype='step', color='c')

hcc1 = plt.hist(np.log10(numu['reco_energy'][dis][CCdis][CCdisNu]), nb, lgE_r, 
         weights=(numu['weight_mu']*w)[dis][CCdis][CCdisNu],
         histtype='step', color='r', linestyle=':')
hnc1 = plt.hist(np.log10(numu['reco_energy'][dis][NCdis][NCdisNu]), nb, lgE_r, 
         weights=(numu['weight_mu']*w)[dis][NCdis][NCdisNu],
         histtype='step', color='orange', linestyle=':')

hcc2 = plt.hist(np.log10(numu['reco_energy'][dis][CCdis][CCdisNu]), nb, lgE_r, 
         weights=(numu['weight_mu']*wc)[dis][CCdis][CCdisNu],
         histtype='step', color='r', linestyle='--')
hnc2 = plt.hist(np.log10(numu['reco_energy'][dis][NCdis][NCdisNu]), nb, lgE_r, 
         weights=(numu['weight_mu']*wc)[dis][NCdis][NCdisNu],
         histtype='step', color='orange', linestyle='--')

ax2 = plt.axes(rect2)

ax2.step(hcc0[1][:-1], hcc1[0]-hcc2[0], color='r')

ax2.step(hcc0[1][:-1], hcc1[0]-hcc0[0], color='g')
ax2.step(hcc0[1][:-1], hcc2[0]-hcc0[0], color='y')
ax2.step(hnc0[1][:-1], hnc1[0]-hnc2[0], color='orange', linestyle=':')

plt.grid(alpha=0.2)
plt.show()

# %%
fig = plt.figure(1, figsize=(7, 5))
ax = plt.axes(rect1)

hcc0 = plt.hist(np.log10(numu['reco_energy'][dis][CCdis][CCdisNu]), nb, lgE_r, 
         weights=numu['weight_mu'][dis][CCdis][CCdisNu],
         histtype='step', color='r')
hnc0 = plt.hist(np.log10(numu['reco_energy'][dis][NCdis][NCdisNu]), nb, lgE_r, 
         weights=numu['weight_mu'][dis][NCdis][NCdisNu],
         histtype='step', color='orange')

# plt.hist(np.log10(numu['reco_energy'][~dis][CCnotdis][CCnotdisNu]), nb, lgE_r, 
#          weights=numu['weight_mu'][~dis][CCnotdis][CCnotdisNu],
#          histtype='step', color='b')
# plt.hist(np.log10(numu['reco_energy'][~dis][NCnotdis][NCnotdisNu]), nb, lgE_r, 
#          weights=numu['weight_mu'][~dis][NCnotdis][NCnotdisNu],
#          histtype='step', color='c')

hcc1 = plt.hist(np.log10(numu['reco_energy'][dis][CCdis][CCdisNu]), nb, lgE_r, 
         weights=(numu['weight_mu']*w)[dis][CCdis][CCdisNu],
         histtype='step', color='r', linestyle=':')
hnc1 = plt.hist(np.log10(numu['reco_energy'][dis][NCdis][NCdisNu]), nb, lgE_r, 
         weights=(numu['weight_mu']*w)[dis][NCdis][NCdisNu],
         histtype='step', color='orange', linestyle=':')

hcc2 = plt.hist(np.log10(numu['reco_energy'][dis][CCdis][CCdisNu]), nb, lgE_r, 
         weights=(numu['weight_mu']*wc)[dis][CCdis][CCdisNu],
         histtype='step', color='r', linestyle='--')
hnc2 = plt.hist(np.log10(numu['reco_energy'][dis][NCdis][NCdisNu]), nb, lgE_r, 
         weights=(numu['weight_mu']*wc)[dis][NCdis][NCdisNu],
         histtype='step', color='orange', linestyle='--')

ax2 = plt.axes(rect2)

ax2.plot(hcc0[1][:-1], hcc1[0]-hcc2[0], color='r' )

ax2.plot(hcc0[1][:-1], hcc1[0]-hcc0[0], color='g' )
ax2.plot(hnc0[1][:-1], hnc1[0]-hnc2[0], color='orange', linestyle=':')

plt.grid(alpha=0.2)
plt.show()

# %%
hcc1[0].sum()*m
# Out:
# 32136.022590586163

# %%
hcc0[0].sum()*m
# Out:
# 28464.255954974957

# %%
numu['weight'].sum()*m
# Out:
# 44986.02121245818

# %%
fig = plt.figure(1, figsize=(7, 5))
ax = plt.axes(rect1)

plt.hist(np.log10(numu['energy'][dis][CCdis][CCdisNuBar]), nb, lgE_r, 
         weights=numu['weight_mu'][dis][CCdis][CCdisNuBar],
         histtype='step', color='r')
plt.hist(np.log10(numu['energy'][dis][NCdis][NCdisNuBar]), nb, lgE_r, 
         weights=numu['weight_mu'][dis][NCdis][NCdisNuBar],
         histtype='step', color='orange')

# plt.hist(np.log10(numu['energy'][~dis][CCnotdis][CCnotdisNuBar]), nb, lgE_r, 
#          weights=numu['weight_mu'][~dis][CCnotdis][CCnotdisNuBar],
#          histtype='step', color='b')
# plt.hist(np.log10(numu['energy'][~dis][NCnotdis][NCnotdisNuBar]), nb, lgE_r, 
#          weights=numu['weight_mu'][~dis][NCnotdis][NCnotdisNuBar],
#          histtype='step', color='c')

plt.hist(np.log10(numu['energy'][dis][CCdis][CCdisNuBar]), nb, lgE_r, 
         weights=(numu['weight_mu']*w)[dis][CCdis][CCdisNuBar],
         histtype='step', color='r', linestyle=':')
plt.hist(np.log10(numu['energy'][dis][NCdis][NCdisNuBar]), nb, lgE_r, 
         weights=(numu['weight_mu']*w)[dis][NCdis][NCdisNuBar],
         histtype='step', color='orange', linestyle=':')

plt.grid(alpha=0.2)
plt.show()

# %%
fig = plt.figure(1, figsize=(7, 5))
ax = plt.axes(rect1)

plt.hist(np.log10(numu['reco_energy'][dis][CCdis][CCdisNu]), nb, lgE_r, 
         weights=numu['weight_mu'][dis][CCdis][CCdisNu],
         histtype='step', color='r')
plt.hist(np.log10(numu['reco_energy'][dis][NCdis][NCdisNu]), nb, lgE_r, 
         weights=numu['weight_mu'][dis][NCdis][NCdisNu],
         histtype='step', color='orange')

# plt.hist(np.log10(numu['reco_energy'][~dis][CCnotdis][CCnotdisNu]), nb, lgE_r, 
#          weights=numu['weight_mu'][~dis][CCnotdis][CCnotdisNu],
#          histtype='step', color='b')
# plt.hist(np.log10(numu['reco_energy'][~dis][NCnotdis][NCnotdisNu]), nb, lgE_r, 
#          weights=numu['weight_mu'][~dis][NCnotdis][NCnotdisNu],
#          histtype='step', color='c')

plt.hist(np.log10(numu['reco_energy'][dis][CCdis][CCdisNu]), nb, lgE_r, 
         weights=(numu['weight_mu']*w)[dis][CCdis][CCdisNu],
         histtype='step', color='r', linestyle=':')
plt.hist(np.log10(numu['reco_energy'][dis][NCdis][NCdisNu]), nb, lgE_r, 
         weights=(numu['weight_mu']*w)[dis][NCdis][NCdisNu],
         histtype='step', color='orange', linestyle=':')


plt.grid(alpha=0.2)
plt.show()

# %%
fig = plt.figure(1, figsize=(7, 5))
ax = plt.axes(rect1)

plt.hist(np.log10(numu['reco_energy'][dis][CCdis][CCdisNuBar]), nb, lgE_r, 
         weights=numu['weight_mu'][dis][CCdis][CCdisNuBar],
         histtype='step', color='r')
plt.hist(np.log10(numu['reco_energy'][dis][NCdis][NCdisNuBar]), nb, lgE_r, 
         weights=numu['weight_mu'][dis][NCdis][NCdisNuBar],
         histtype='step', color='orange')

# plt.hist(np.log10(numu['reco_energy'][~dis][CCnotdis][CCnotdisNuBar]), nb, lgE_r, 
#          weights=numu['weight_mu'][~dis][CCnotdis][CCnotdisNuBar],
#          histtype='step', color='b')
# plt.hist(np.log10(numu['reco_energy'][~dis][NCnotdis][NCnotdisNuBar]), nb, lgE_r, 
#          weights=numu['weight_mu'][~dis][NCnotdis][NCnotdisNuBar],
#          histtype='step', color='c')

plt.hist(np.log10(numu['reco_energy'][dis][CCdis][CCdisNuBar]), nb, lgE_r, 
         weights=(numu['weight_mu']*w)[dis][CCdis][CCdisNuBar],
         histtype='step', color='r', linestyle=':')
plt.hist(np.log10(numu['reco_energy'][dis][NCdis][NCdisNuBar]), nb, lgE_r, 
         weights=(numu['weight_mu']*w)[dis][NCdis][NCdisNuBar],
         histtype='step', color='orange', linestyle=':')

plt.grid(alpha=0.2)
plt.show()

# %%
fig = plt.figure(1, figsize=(7, 5))
ax = plt.axes(rect1)



hcc0 = plt.hist(np.log10(numu['GENIE_Ws'][dis][CCdis][CCdisNu]), nb, lgE_r, 
         weights=numu['weight_mu'][dis][CCdis][CCdisNu],
         histtype='step', color='r')
# hnc0 = plt.hist(np.log10(numu['GENIE_Ws'][dis][NCdis][NCdisNu]), nb, lgE_r, 
#          weights=numu['weight_mu'][dis][NCdis][NCdisNu],
#          histtype='step', color='orange')

hcc_c = plt.hist(np.log10(numu['GENIE_Ws'][dis][CCdis][CCdisNu]), nb, lgE_r, 
         weights=numu['weight_mu'][dis][CCdis][CCdisNu]*w_CCNu_c,
         histtype='step', color='r', linestyle=':')
# hnc_c = plt.hist(np.log10(numu['GENIE_Ws'][dis][NCdis][NCdisNu]), nb, lgE_r, 
#          weights=numu['weight_mu'][dis][NCdis][NCdisNu]*w_NCNu_c,
#          histtype='step', color='orange', linestyle=':')

hcc_lin = plt.hist(np.log10(numu['GENIE_Ws'][dis][CCdis][CCdisNu]), nb, lgE_r, 
         weights=numu['weight_mu'][dis][CCdis][CCdisNu]*w_CCNu_lin,
         histtype='step', color='r', linestyle='--')
# hnc_lin = plt.hist(np.log10(numu['GENIE_Ws'][dis][NCdis][NCdisNu]), nb, lgE_r, 
#          weights=numu['weight_mu'][dis][NCdis][NCdisNu]*w_NCNu_lin,
#          histtype='step', color='orange', linestyle='--')

plt.grid(alpha=0.2)
ax2 = plt.axes(rect2)

ax2.step(hcc0[1][:-1], hcc_lin[0]-hcc_c[0], color='r')

ax2.step(hcc0[1][:-1], hcc_c[0]-hcc0[0], color='g')
ax2.step(hcc0[1][:-1], hcc_lin[0]-hcc0[0], color='y')
ax2.step(hnc0[1][:-1], hnc_c[0]-hnc_lin[0], color='orange', linestyle=':')

plt.grid(alpha=0.2)
plt.show()
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in log10
#
# /home/maria/.local/lib/python2.7/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/maria/.local/lib/python2.7/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in log10
#   del sys.path[0]
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:20: RuntimeWarning: invalid value encountered in log10
